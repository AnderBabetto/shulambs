# %%
import pandas as pd

# %%
data = pd.read_excel('SEEG11.1-DADOS-NACIONAIS.xlsx')

# %%
data.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1
# 0         NaN  Base de Dados do Sistema de Estimativa de Emis...
# 1         NaN                                         SEEG v11.1
# 2         NaN                                   Novembro de 2023
# 3         NaN                                                NaN
# 4         NaN                         Descrição geral do arquivo

# %%
data.shape
# Out:
# (34, 2)

# %%
data
# Out:
#     Unnamed: 0                                         Unnamed: 1
# 0          NaN  Base de Dados do Sistema de Estimativa de Emis...
# 1          NaN                                         SEEG v11.1
# 2          NaN                                   Novembro de 2023
# 3          NaN                                                NaN
# 4          NaN                         Descrição geral do arquivo
# 5          NaN  Este arquivo contém, na aba Dados, os dados do...
# 6          NaN                                                NaN
# 7          NaN                         Uso dos dados e como citar
# 8          NaN  O uso desta planilha é livre, no entanto solic...
# 9          NaN  Fonte: Sistema de Estimativa de Emissões e Rem...
# 10         NaN                                                NaN
# 11         NaN                Emissões brutas e emissões líquidas
# 12         NaN  No campo "Emissões/Remoções/Bunker" dos Dados,...
# ...
